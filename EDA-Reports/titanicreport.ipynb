# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df=pd.read_csv('train.csv')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'train.csv'

# %%
df.head()

# %%
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.34.2)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.68.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.5.20)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# !pip install ydata-profiling --upgrade
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.13.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (2.34.2)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.68.3)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.14.6)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (26.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2026.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2026.5.20)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.2)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.6.1)
# Requirement already satisfied: puremagic in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# !pip install visions
# !pip install numba
# !pip install scipy
# !pip install phik
# Out:
# Requirement already satisfied: visions in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (0.8.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions) (2.3.5)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions) (2.3.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions) (26.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions) (3.6.1)
# Requirement already satisfied: multimethod>=1.4 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions) (1.12)
# Requirement already satisfied: puremagic in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from visions) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->visions) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->visions) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.0.0->visions) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->visions) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: numba in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (0.62.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from numba) (0.45.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from numba) (2.3.5)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from scipy) (2.3.5)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# Requirement already satisfied: phik in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (0.12.5)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from phik) (2.3.5)
# Requirement already satisfied: scipy>=1.5.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from phik) (1.16.3)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from phik) (2.3.3)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from phik) (3.10.0)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from phik) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=2.2.3->phik) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.25.1->phik) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.25.1->phik) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade setuptools
# Out:
# Requirement already satisfied: setuptools in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (69.5.1)
# Collecting setuptools
#   Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Using cached setuptools-82.0.1-py3-none-any.whl (1.0 MB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
# Successfully installed setuptools-82.0.1
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# !pip install setuptools==69.5.1
# Out:
# Collecting setuptools==69.5.1
#   Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1
# Successfully installed setuptools-69.5.1
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
# !pip install --force-reinstall setuptools==69.5.1
# Out:
# Collecting setuptools==69.5.1
#   Using cached setuptools-69.5.1-py3-none-any.whl.metadata (6.2 kB)
# Using cached setuptools-69.5.1-py3-none-any.whl (894 kB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
# Successfully installed setuptools-69.5.1
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import pkg_resources
print("Working Fine")
# Out:
# Working Fine
# C:\Users\Hp\AppData\Local\Temp\ipykernel_4244\209098435.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe

# %%
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (2.3.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (2.3.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (2.3.5)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (4.68.3)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (1.16.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (3.1.6)
# Requirement already satisfied: importlib_resources>=1.2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from sweetviz) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (12.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2026.2)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Hp\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import sweetviz as sv

report = sv.analyze(df)
report.show_html("EDA_Report.html")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 import sweetviz as sv
#       2
# ----> 3 report = sv.analyze(df)
#       4 report.show_html("EDA_Report.html")
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

df = pd.read_csv("train.csv")
df.head()

# %%
import sweetviz as sv

report = sv.analyze(df)
report.show_html("EDA_Report.html")
